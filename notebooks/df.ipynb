# %%
import pandas as pd
import os

# %%
def list_files_in_folder(folder_path):
    if not os.path.exists(folder_path):
        print(f"La carpeta '{folder_path}' no existe.")
        return []

    if not os.path.isdir(folder_path):
        print(f"'{folder_path}' no es una carpeta.")
        return []

    file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    return file_paths

# %%
folder_path = r'C:\Users\jherrera.FINANCREDITOS\OneDrive - Financreditos S.A.S\NodosLab\Nodos_Report\data\procesed_data\df'

file_paths = list_files_in_folder(folder_path)

# %%
dic_df={}
for file in file_paths:
    name_file=os.path.splitext(os.path.basename(file))
    df = pd.read_csv(file)
    dic_df[name_file[0]]=df
# Out:
# df_efect
# C:\Users\jherrera.FINANCREDITOS\AppData\Local\Temp\ipykernel_16452\2914140661.py:5: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# df_gestion_month
# df_goals
# df_promises
# df_seguimientos_promesas

# %%
dic_df['df_promises']
# Out:
#        ACCOUNT_NUMBER  ID_GESTION ENTIDAD_ID  IDENTIFICACION  \
# 0            18870793         NaN    NATURA2      1114816601
# 1            18870793         NaN    NATURA2      1114816601
# 2            18870793         NaN    NATURA2      1114816601
# 3            18870793         NaN    NATURA2      1114816601
# 4            19632303         NaN    NATURA2        76285567
# ...               ...         ...        ...             ...
# 19318        18909634         NaN    NATURA2        64541053
# 19319        18915903         NaN    NATURA2      1235041648
# 19320        18915903         NaN    NATURA2      1235041648
# 19321        18926135         NaN    NATURA2        32617382
# 19322        18926135         NaN    NATURA2        32617382
#
#                   HISTORY_DATE  GESTOR_ID    PROMISE_NEXT_DATE  \
# 0      2023-10-07 13:24:05.963   yagarcia  2023-10-09 13:24:04
# 1      2023-10-07 13:24:05.963   yagarcia  2023-10-09 13:24:04
# 2      2023-10-07 13:24:05.963   yagarcia  2023-10-09 13:24:04
# 3      2023-10-07 13:24:05.963   yagarcia  2023-10-09 13:24:04
# 4      2023-10-07 13:16:00.433   yagarcia  2023-10-09 13:15:58
# ...                        ...        ...                  ...
# 19318  2023-07-04 07:50:41.937    kmortiz  2023-07-04 07:50:41
# 19319  2023-07-04 07:40:08.620    kmortiz  2023-07-05 07:40:08
# 19320  2023-07-04 07:40:08.620    kmortiz  2023-07-05 07:40:08
# 19321  2023-07-04 07:25:47.617  vaherrera  2023-07-04 07:25:47
# 19322  2023-07-04 07:25:47.617  vaherrera  2023-07-04 07:25:47
#
#        PROMISE_NEXT_AMOUNT PROMISE_STATE PROMISE_TYPE             NOMBRE  \
# 0                 112900.0     PENDIENTE       SIMPLE        YURI GARCIA
# 1                 112900.0     PENDIENTE       SIMPLE        YURI GARCIA
# 2                 112900.0     PENDIENTE       SIMPLE        YURI GARCIA
# 3                 112900.0     PENDIENTE       SIMPLE        YURI GARCIA
# 4                  50000.0     PENDIENTE       SIMPLE        YURI GARCIA
# ...                    ...           ...          ...                ...
# 19318             250000.0     PENDIENTE       SIMPLE        KEYLA ORTIZ
# 19319              60000.0     PENDIENTE       SIMPLE        KEYLA ORTIZ
# 19320              60000.0     PENDIENTE       SIMPLE        KEYLA ORTIZ
# 19321             134200.0     PENDIENTE       SIMPLE  VALENTINE HERRERA
# 19322             134200.0     PENDIENTE       SIMPLE  VALENTINE HERRERA
#
#       COORDINADORA SUCURSAL FECHA_INGRESO  MES               llave
# 0               IC   BOGOTA    2023-03-27   10       YURI GARCIA10
# 1               IC   BOGOTA    2023-03-27   10       YURI GARCIA10
# 2               IC   BOGOTA    2023-03-27   10       YURI GARCIA10
# 3               IC   BOGOTA    2023-03-27   10       YURI GARCIA10
# 4               IC   BOGOTA    2023-03-27   10       YURI GARCIA10
# ...            ...      ...           ...  ...                 ...
# 19318           IC   BOGOTA    2023-02-06    7        KEYLA ORTIZ7
# 19319           IC   BOGOTA    2023-02-06    7        KEYLA ORTIZ7
# 19320           IC   BOGOTA    2023-02-06    7        KEYLA ORTIZ7
# 19321           IC   BOGOTA    2023-03-10    7  VALENTINE HERRERA7
# 19322           IC   BOGOTA    2023-03-10    7  VALENTINE HERRERA7
#
# [19323 rows x 16 columns]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
file_names_without_extension
# Out:
# ['df_efect',
#  'df_gestion_month',
#  'df_goals',
#  'df_promises',
#  'df_seguimientos_promesas']
